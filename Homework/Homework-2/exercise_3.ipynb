# %%
import numpy as np
import scipy as sp
import scipy.linalg
import matplotlib.pyplot as plt
from hw2_exercise_3 import *
# %matplotlib inline

# %%
(t_vals, mu, Q) = propagateDistribution(mu_0 = 1)
plt.plot(t_vals, mu)
plt.plot(t_vals,Q)

# %%
(t_vals, mu, Q) = propagateDistribution(mu_0 = 1, Q_0 = 0)
plt.plot(t_vals, mu)
plt.plot(t_vals,Q)

# %%
propagateDistribution(Q_0 = 2, showPlot=True)
propagateDistribution(Q_0 = 0, showPlot=True)
plt.xlabel('t')
plt.show()
# Out:
# A_d is 0.975309912028
# W_d is 0.0487705754993
# A_d is 0.975309912028
# W_d is 0.0487705754993
